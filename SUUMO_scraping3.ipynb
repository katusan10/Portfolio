# %%
from time import sleep
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://suumo.jp/chintai/tokyo/sc_shinjuku/?page={}'

d_list = []

for i in range(1,3):
    print('d_listの大きさ : ', len(d_list))
    target_url = url.format(i)
    print(target_url)
    r = requests.get(target_url)
    
    sleep(1)
    
    soup = BeautifulSoup(r.text)

    # すべての物件情報（２０件）を取得する
    contents = soup.find_all('div', class_='cassetteitem')

    # 各物件情報をforループで取得する
    for content in contents:

        # 物件情報と部屋情報を取得しておく
        detail = content.find('div', class_='cassetteitem_content')
        table = content.find('table', class_='cassetteitem_other')

        # 物件情報から必要な情報を取得する
        title = detail.find('div', class_='cassetteitem_content-title').text
        address = detail.find('li', class_='cassetteitem_detail-col1').text
        access = detail.find('li', class_='cassetteitem_detail-col2').text
        age = detail.find('li', class_='cassetteitem_detail-col3').text

        # 部屋情報のブロックから、各部屋情報を取得する
        tr_tags = table.find_all('tr', class_='js-cassette_link')

        # 各部屋情報をforループで取得する
        for tr_tag in tr_tags:

            # 部屋情報の行から、欲しい情報を取得する
            floor, price, first_fee, capacity = tr_tag.find_all('td')[2:6]

            # さらに細かい情報を取得する
            fee, management_fee = price.find_all('li')
            deposit, gratuity = first_fee.find_all('li')
            madori, menseki = capacity.find_all('li')

            # 取得したすべての情報を辞書に格納する
            d = {
                'title': title,
                'address': address,
                'access': access,
                'age': age,
                'floor': floor.text,
                'fee': fee.text,
                'management_fee': management_fee.text,
                'deposit': deposit.text,
                'gratuity': gratuity.text,
                'madori': madori.text,
                'menseki': menseki.text
            }

            # 取得した辞書をd_listに格納する
            d_list.append(d)
# Out:
# d_listの大きさ :  0
# https://suumo.jp/chintai/tokyo/sc_shinjuku/?page=1
# d_listの大きさ :  129
# https://suumo.jp/chintai/tokyo/sc_shinjuku/?page=2

# %%
d_list[:2]
# Out:
# [{'title': '西早稲田クレセントマンション',
#   'address': '東京都新宿区西早稲田３',
#   'access': '\n東京メトロ副都心線/西早稲田駅 歩6分\n東京メトロ東西線/高田馬場駅 歩8分\nＪＲ山手線/高田馬場駅 歩12分\n',
#   'age': '\n築35年\n6階建\n',
#   'floor': '\r\n\t\t\t\t\t\t\t\t\t\t\t2階',
#   'fee': '16.9万円',
#   'management_fee': '15000円',
#   'deposit': '16.9万円',
#   'gratuity': '-',
#   'madori': '3LDK',
#   'menseki': '67.87m2'},
#  {'title': 'アーバネックス西新宿',
#   'address': '東京都新宿区北新宿１',
#   'access': '\n東京メトロ丸ノ内線/西新宿駅 歩6分\nＪＲ中央線/大久保駅 歩10分\n都営大江戸線/都庁前駅 歩12分\n',
#   'age': '\n築6年\n13階建\n',
#   'floor': '\r\n\t\t\t\t\t\t\t\t\t\t\t4階',
#   'fee': '11.9万円',
#   'management_fee': '10000円',
#   'deposit': '11.9万円',
#   'gratuity': '-',
#   'madori': '1K',
#   'menseki': '26.09m2'}]

# %%
df = pd.DataFrame(d_list)
df
# 253  \r\n\t\t\t\t\t\t\t\t\t\t\t5階   9.4万円              -   9.4万円        -
# 254  \r\n\t\t\t\t\t\t\t\t\t\t\t9階   8.9万円         10500円       -    8.9万円
# 255  \r\n\t\t\t\t\t\t\t\t\t\t\t1階   7.5万円          3000円   7.5万円    7.5万円
# 256  \r\n\t\t\t\t\t\t\t\t\t\t\t3階  11.9万円          6000円  11.9万円   11.9万円
#
#     madori  menseki
# 0     3LDK  67.87m2
# 1       1K  26.09m2
# 2       1K  25.66m2
# 3       1K  26.09m2
# 4     1LDK  32.11m2
# ..     ...      ...
# 252     1K     21m2
# 253     1K     21m2
# 254     1K  23.08m2
# 255     1K  23.98m2
# 256    1DK  32.09m2
#
# [257 rows x 11 columns]

# %%
# 先頭5つのデーターを閲覧
df.head()
# Out:
#             title      address  \
# 0  西早稲田クレセントマンション  東京都新宿区西早稲田３
# 1      アーバネックス西新宿   東京都新宿区北新宿１
# 2      アーバネックス西新宿   東京都新宿区北新宿１
# 3      アーバネックス西新宿   東京都新宿区北新宿１
# 4      アーバネックス西新宿   東京都新宿区北新宿１
#
#                                               access            age  \
# 0  \n東京メトロ副都心線/西早稲田駅 歩6分\n東京メトロ東西線/高田馬場駅 歩8分\nＪＲ山...  \n築35年\n6階建\n
# 1  \n東京メトロ丸ノ内線/西新宿駅 歩6分\nＪＲ中央線/大久保駅 歩10分\n都営大江戸線/...  \n築6年\n13階建\n
# 2  \n東京メトロ丸ノ内線/西新宿駅 歩6分\nＪＲ中央線/大久保駅 歩10分\n都営大江戸線/...  \n築6年\n13階建\n
# 3  \n東京メトロ丸ノ内線/西新宿駅 歩6分\nＪＲ中央線/大久保駅 歩10分\n都営大江戸線/...  \n築6年\n13階建\n
# 4  \n東京メトロ丸ノ内線/西新宿駅 歩6分\nＪＲ中央線/大久保駅 歩10分\n都営大江戸線/...  \n築6年\n13階建\n
#
#                           floor     fee management_fee deposit gratuity  \
# 0  \r\n\t\t\t\t\t\t\t\t\t\t\t2階  16.9万円         15000円  16.9万円        -
# 1  \r\n\t\t\t\t\t\t\t\t\t\t\t4階  11.9万円         10000円  11.9万円        -
# 2  \r\n\t\t\t\t\t\t\t\t\t\t\t7階  12.2万円         10000円  12.2万円   12.2万円
# 3  \r\n\t\t\t\t\t\t\t\t\t\t\t5階  12.7万円         10000円  12.7万円   12.7万円
# 4  \r\n\t\t\t\t\t\t\t\t\t\t\t5階  14.7万円         12000円  14.7万円   14.7万円
#
#   madori  menseki
# 0   3LDK  67.87m2
# 1     1K  26.09m2
# 2     1K  25.66m2
# 3     1K  26.09m2
# 4   1LDK  32.11m2

# %%
# dfの大きさを確認する
df.shape
# Out:
# (257, 11)

# %%
# 物件名の重複を削除して、その大きさを確認する
len(df.title.unique())
# Out:
# 40

# %%
# to_csv()を使って、データフレームをCSV出力する
df.to_csv('test.csv', index=None, encoding='utf-8-sig')
